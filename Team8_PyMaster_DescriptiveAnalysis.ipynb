# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Q1. What is the "Probable" COVID-19 rate across different genders?
# ##### Importance: Health outcomes often differ by sex. This helps identify if one gender was reporting symptoms more frequently in Ontario during April 2020.

# %%
gender_risk = df2_clean.groupby('sex')['is_probable'].mean() * 100
print("\nProbable Case Rate by Sex (%):")
print(gender_risk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 gender_risk = df2_clean.groupby('sex')['is_probable'].mean() * 100
#       2 print("\nProbable Case Rate by Sex (%):")
#       3 print(gender_risk)
#
# NameError: name 'df2_clean' is not defined
