# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import os
os.getcwd()
# Out:
# 'C:\\Users\\ajaya\\Documents\\GitHub\\Team8_PyMaster_PythonHackathon_December25'

# %%
schema_1 = pd.read_csv(r"C:\Users\ajaya\Desktop\NUMPYNINJA\HACKATHON\HACKATHON DETAILS\schema_1_ontario_final.csv")
schema_2 = pd.read_csv(r"C:\Users\ajaya\Desktop\NUMPYNINJA\HACKATHON\HACKATHON DETAILS\schema_2_ontario_final.csv")
schema_3 = pd.read_csv(r"C:\Users\ajaya\Desktop\NUMPYNINJA\HACKATHON\HACKATHON DETAILS\schema_3_ontario_final.csv")

# %%
schema_1 #Reading Schema 1 file
# Out:
#         week  fsa probable vulnerable is_most_recent fever_chills_shakes  \
# 0         13  L4C        n          n              y                   n
# 1         13  P1H        y          y              y                   n
# 2         14  N2J        n          y              y                   n
# 3         13  N1G        n          n              y                   n
# 4         13  M1P        n          y              n                   n
# ...      ...  ...      ...        ...            ...                 ...
# 263634    14  N0G        n          y              y                   n
# 263635    14  M6P        n          y              y                   n
# 263636    13  L3X        n          n              y                   n
# 263637    14  M6R        n          n              y                   n
# 263638    13  M8V        y          y              y                   n
#
#        cough shortness_of_breath over_60 any_medical_conditions  \
# 0          n                   n       n                      n
# 1          n                   n       y                      y
# 2          n                   n       y                      n
# 3          n                   n       n                      n
# 4          n                   n       n                      y
# ...      ...                 ...     ...                    ...
# 263634     n                   n       n                      y
# 263635     n                   n       n                      y
# 263636     n                   n       n                      n
# 263637     n                   n       n                      n
# 263638     n                   n       y                      n
#
#        travel_outside_canada contact_with_illness
# 0                          n                    n
# 1                          n                    y
# 2                          n                    n
# 3                          n                    n
# 4                          n                    n
# ...                      ...                  ...
# 263634                     n                    n
# 263635                     n                    n
# 263636                     n                    n
# 263637                     n                    n
# 263638                     y                    y
#
# [263639 rows x 12 columns]

# %%
schema_1.columns
# Out:
# Index(['week', 'fsa', 'probable', 'vulnerable', 'is_most_recent',
#        'fever_chills_shakes', 'cough', 'shortness_of_breath', 'over_60',
#        'any_medical_conditions', 'travel_outside_canada',
#        'contact_with_illness'],
#       dtype='object')

# %%
schema_2
# Out:
#        week  fsa probable vulnerable is_most_recent fever_chills_shakes cough  \
# 0        15  M1P        n          n              y                   n     n
# 1        16  N2P        n          y              y                   n     n
# 2        16  N2P        n          y              n                   n     n
# 3        16  M4P        n          n              y                   n     n
# 4        16  L4N        n          n              y                   n     n
# ...     ...  ...      ...        ...            ...                 ...   ...
# 14927    15  L6B        n          y              y                   n     n
# 14928    15  L6J        n          n              y                   n     n
# 14929    16  N9V        n          n              y                   n     n
# 14930    16  L3Z        n          n              y                   n     n
# 14931    16  L6J        n          n              y                   n     n
#
#       shortness_of_breath any_medical_conditions travel_outside_canada  \
# 0                       n                      y                     n
# 1                       n                      y                     n
# 2                       n                      y                     n
# 3                       n                      y                     n
# 4                       n                      y                     n
# ...                   ...                    ...                   ...
# 14927                   n                      y                     n
# 14928                   n                      y                     n
# 14929                   n                      y                     n
# 14930                   n                      y                     n
# 14931                   n                      y                     n
#
#       contact_with_illness   symptoms                      conditions  \
# 0                        n        NaN                             NaN
# 1                        n  runnyNose               highBloodPressure
# 2                        n        NaN               highBloodPressure
# 3                        n        NaN                             NaN
# 4                        n        NaN                             NaN
# ...                    ...        ...                             ...
# 14927                    n        NaN  heartDisease;breathingProblems
# 14928                    n  runnyNose                             NaN
# 14929                    n        NaN                             NaN
# 14930                    n        NaN                             NaN
# 14931                    n        NaN                             NaN
#
#        ethnicity sex             needs  age_1
# 0            NaN   m               NaN  45-64
# 1          asian   m             other  45-64
# 2          asian   m             other  45-64
# 3      caucasian   f  emotionalSupport  26-44
# 4      caucasian   f  emotionalSupport  26-44
# ...          ...  ..               ...    ...
# 14927        NaN   f               NaN  26-44
# 14928        NaN   f               NaN  45-64
# 14929  caucasian   m             other  26-44
# 14930      asian   m             other  26-44
# 14931  caucasian   m             other  26-44
#
# [14932 rows x 17 columns]

# %%
schema_2.columns
# Out:
# Index(['week', 'fsa', 'probable', 'vulnerable', 'is_most_recent',
#        'fever_chills_shakes', 'cough', 'shortness_of_breath',
#        'any_medical_conditions', 'travel_outside_canada',
#        'contact_with_illness', 'symptoms', 'conditions', 'ethnicity', 'sex',
#        'needs', 'age_1'],
#       dtype='object')

# %%
combined_df = pd.concat([schema_1, schema_2], ignore_index=True)
combined_df
# Out:
#         week  fsa probable vulnerable is_most_recent fever_chills_shakes  \
# 0         13  L4C        n          n              y                   n
# 1         13  P1H        y          y              y                   n
# 2         14  N2J        n          y              y                   n
# 3         13  N1G        n          n              y                   n
# 4         13  M1P        n          y              n                   n
# ...      ...  ...      ...        ...            ...                 ...
# 278566    15  L6B        n          y              y                   n
# 278567    15  L6J        n          n              y                   n
# 278568    16  N9V        n          n              y                   n
# 278569    16  L3Z        n          n              y                   n
# 278570    16  L6J        n          n              y                   n
#
#        cough shortness_of_breath over_60 any_medical_conditions  \
# 0          n                   n       n                      n
# 1          n                   n       y                      y
# 2          n                   n       y                      n
# 3          n                   n       n                      n
# 4          n                   n       n                      y
# ...      ...                 ...     ...                    ...
# 278566     n                   n     NaN                      y
# 278567     n                   n     NaN                      y
# 278568     n                   n     NaN                      y
# 278569     n                   n     NaN                      y
# 278570     n                   n     NaN                      y
#
#        travel_outside_canada contact_with_illness   symptoms  \
# 0                          n                    n        NaN
# 1                          n                    y        NaN
# 2                          n                    n        NaN
# 3                          n                    n        NaN
# 4                          n                    n        NaN
# ...                      ...                  ...        ...
# 278566                     n                    n        NaN
# 278567                     n                    n  runnyNose
# 278568                     n                    n        NaN
# 278569                     n                    n        NaN
# 278570                     n                    n        NaN
#
#                             conditions  ethnicity  sex  needs  age_1
# 0                                  NaN        NaN  NaN    NaN    NaN
# 1                                  NaN        NaN  NaN    NaN    NaN
# 2                                  NaN        NaN  NaN    NaN    NaN
# 3                                  NaN        NaN  NaN    NaN    NaN
# 4                                  NaN        NaN  NaN    NaN    NaN
# ...                                ...        ...  ...    ...    ...
# 278566  heartDisease;breathingProblems        NaN    f    NaN  26-44
# 278567                             NaN        NaN    f    NaN  45-64
# 278568                             NaN  caucasian    m  other  26-44
# 278569                             NaN      asian    m  other  26-44
# 278570                             NaN  caucasian    m  other  26-44
#
# [278571 rows x 18 columns]

# %%
combined_df.columns
# Out:
# Index(['week', 'fsa', 'probable', 'vulnerable', 'is_most_recent',
#        'fever_chills_shakes', 'cough', 'shortness_of_breath', 'over_60',
#        'any_medical_conditions', 'travel_outside_canada',
#        'contact_with_illness', 'symptoms', 'conditions', 'ethnicity', 'sex',
#        'needs', 'age_1'],
#       dtype='object')

# %%
week_to_month = {13: 'April', 14: 'April', 15: 'April', 16:'April'}
combined_df['month'] = combined_df['week'].map(week_to_month)

# %%
combined_df
# Out:
#         week  fsa probable vulnerable is_most_recent fever_chills_shakes  \
# 0         13  L4C        n          n              y                   n
# 1         13  P1H        y          y              y                   n
# 2         14  N2J        n          y              y                   n
# 3         13  N1G        n          n              y                   n
# 4         13  M1P        n          y              n                   n
# ...      ...  ...      ...        ...            ...                 ...
# 278566    15  L6B        n          y              y                   n
# 278567    15  L6J        n          n              y                   n
# 278568    16  N9V        n          n              y                   n
# 278569    16  L3Z        n          n              y                   n
# 278570    16  L6J        n          n              y                   n
#
#        cough shortness_of_breath over_60 any_medical_conditions  \
# 0          n                   n       n                      n
# 1          n                   n       y                      y
# 2          n                   n       y                      n
# 3          n                   n       n                      n
# 4          n                   n       n                      y
# ...      ...                 ...     ...                    ...
# 278566     n                   n     NaN                      y
# 278567     n                   n     NaN                      y
# 278568     n                   n     NaN                      y
# 278569     n                   n     NaN                      y
# 278570     n                   n     NaN                      y
#
#        travel_outside_canada contact_with_illness   symptoms  \
# 0                          n                    n        NaN
# 1                          n                    y        NaN
# 2                          n                    n        NaN
# 3                          n                    n        NaN
# 4                          n                    n        NaN
# ...                      ...                  ...        ...
# 278566                     n                    n        NaN
# 278567                     n                    n  runnyNose
# 278568                     n                    n        NaN
# 278569                     n                    n        NaN
# 278570                     n                    n        NaN
#
#                             conditions  ethnicity  sex  needs  age_1  month
# 0                                  NaN        NaN  NaN    NaN    NaN  April
# 1                                  NaN        NaN  NaN    NaN    NaN  April
# 2                                  NaN        NaN  NaN    NaN    NaN  April
# 3                                  NaN        NaN  NaN    NaN    NaN  April
# 4                                  NaN        NaN  NaN    NaN    NaN  April
# ...                                ...        ...  ...    ...    ...    ...
# 278566  heartDisease;breathingProblems        NaN    f    NaN  26-44  April
# 278567                             NaN        NaN    f    NaN  45-64  April
# 278568                             NaN  caucasian    m  other  26-44  April
# 278569                             NaN      asian    m  other  26-44  April
# 278570                             NaN  caucasian    m  other  26-44  April
#
# [278571 rows x 19 columns]

# %%
combined_df = combined_df.drop(columns=['week'], errors='ignore')

# %%
combined_df #changed week into month and removed week column
# Out:
#         fsa probable vulnerable is_most_recent fever_chills_shakes cough  \
# 0       L4C        n          n              y                   n     n
# 1       P1H        y          y              y                   n     n
# 2       N2J        n          y              y                   n     n
# 3       N1G        n          n              y                   n     n
# 4       M1P        n          y              n                   n     n
# ...     ...      ...        ...            ...                 ...   ...
# 278566  L6B        n          y              y                   n     n
# 278567  L6J        n          n              y                   n     n
# 278568  N9V        n          n              y                   n     n
# 278569  L3Z        n          n              y                   n     n
# 278570  L6J        n          n              y                   n     n
#
#        shortness_of_breath over_60 any_medical_conditions  \
# 0                        n       n                      n
# 1                        n       y                      y
# 2                        n       y                      n
# 3                        n       n                      n
# 4                        n       n                      y
# ...                    ...     ...                    ...
# 278566                   n     NaN                      y
# 278567                   n     NaN                      y
# 278568                   n     NaN                      y
# 278569                   n     NaN                      y
# 278570                   n     NaN                      y
#
#        travel_outside_canada contact_with_illness   symptoms  \
# 0                          n                    n        NaN
# 1                          n                    y        NaN
# 2                          n                    n        NaN
# 3                          n                    n        NaN
# 4                          n                    n        NaN
# ...                      ...                  ...        ...
# 278566                     n                    n        NaN
# 278567                     n                    n  runnyNose
# 278568                     n                    n        NaN
# 278569                     n                    n        NaN
# 278570                     n                    n        NaN
#
#                             conditions  ethnicity  sex  needs  age_1  month
# 0                                  NaN        NaN  NaN    NaN    NaN  April
# 1                                  NaN        NaN  NaN    NaN    NaN  April
# 2                                  NaN        NaN  NaN    NaN    NaN  April
# 3                                  NaN        NaN  NaN    NaN    NaN  April
# 4                                  NaN        NaN  NaN    NaN    NaN  April
# ...                                ...        ...  ...    ...    ...    ...
# 278566  heartDisease;breathingProblems        NaN    f    NaN  26-44  April
# 278567                             NaN        NaN    f    NaN  45-64  April
# 278568                             NaN  caucasian    m  other  26-44  April
# 278569                             NaN      asian    m  other  26-44  April
# 278570                             NaN  caucasian    m  other  26-44  April
#
# [278571 rows x 18 columns]

# %%
schema_3
# Out:
#        month  fsa probable vulnerable fever_chills_shakes cough  \
# 0      April  M4P        n          n                   n     n
# 1      April  M9P        n          n                   n     n
# 2      April  K0L        n          n                   n     n
# 3      April  N9E        n          n                   n     n
# 4      April  L2N        n          n                   n     n
# ...      ...  ...      ...        ...                 ...   ...
# 15529   July  M6P        n          n                   n     n
# 15530   July  K1R        n          n                   n     n
# 15531   July  M4M        n          n                   n     n
# 15532   July  M6P        n          y                   n     n
# 15533   July  K2H        n          n                   n     n
#
#       shortness_of_breath any_medical_conditions travel_outside_canada  \
# 0                       n                      y                     n
# 1                       n                      y                     n
# 2                       n                      y                     n
# 3                       n                      y                     n
# 4                       n                      y                     n
# ...                   ...                    ...                   ...
# 15529                   n                      y                     n
# 15530                   n                      y                     n
# 15531                   n                      y                     n
# 15532                   n                      y                     n
# 15533                   n                      y                     n
#
#       contact_with_illness  ...                             ethnicity  sex  \
# 0                        n  ...                                   NaN  NaN
# 1                        n  ...                             caucasian    f
# 2                        n  ...                                   NaN  NaN
# 3                        n  ...                                   NaN  NaN
# 4                        n  ...                                   NaN  NaN
# ...                    ...  ...                                   ...  ...
# 15529                    n  ...                                   NaN  NaN
# 15530                    n  ...  firstNations;black/african;caucasian  NaN
# 15531                    n  ...                                   NaN  NaN
# 15532                    n  ...                                   NaN    m
# 15533                    n  ...                                   NaN    f
#
#                   needs  age_1 mental_health_impact    travel_work_school  \
# 0        noneOfTheAbove    <26                  NaN                   NaN
# 1                  food    <26             noImpact     stoppedTravelling
# 2        noneOfTheAbove  45-64                  NaN                   NaN
# 3        noneOfTheAbove  45-64                  NaN                   NaN
# 4      financialSupport    <26                  NaN                   NaN
# ...                 ...    ...                  ...                   ...
# 15529  emotionalSupport  45-64                  NaN                   NaN
# 15530  emotionalSupport  26-44                  NaN                   NaN
# 15531    noneOfTheAbove  26-44                  NaN                   NaN
# 15532    noneOfTheAbove    >65             noImpact     didntTravelBefore
# 15533    noneOfTheAbove  45-64           negatively  stillTravelEssential
#
#       self_isolating     media_channels financial_obligations_impact  \
# 0                NaN                NaN                          NaN
# 1                  y  twitter;tv;reddit                          NaN
# 2                NaN                NaN                          NaN
# 3                NaN                NaN                          NaN
# 4                NaN                NaN                          NaN
# ...              ...                ...                          ...
# 15529            NaN                NaN                          NaN
# 15530            NaN                NaN                          NaN
# 15531            NaN                NaN                          NaN
# 15532              n    newspaper;radio                          NaN
# 15533              y                NaN                          NaN
#
#       tobacco_usage
# 0               NaN
# 1                 n
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 15529           NaN
# 15530           NaN
# 15531           NaN
# 15532             n
# 15533             n
#
# [15534 rows x 26 columns]

# %%
schema_3.columns
# Out:
# Index(['month', 'fsa', 'probable', 'vulnerable', 'fever_chills_shakes',
#        'cough', 'shortness_of_breath', 'any_medical_conditions',
#        'travel_outside_canada', 'contact_with_illness', 'contact_in_household',
#        'tested', 'covid_results_date', 'covid_positive', 'symptoms',
#        'conditions', 'ethnicity', 'sex', 'needs', 'age_1',
#        'mental_health_impact', 'travel_work_school', 'self_isolating',
#        'media_channels', 'financial_obligations_impact', 'tobacco_usage'],
#       dtype='object')

# %%
final_df = pd.concat([combined_df, schema_3], ignore_index=True)#combining schema 3
final_df
# Out:
#         fsa probable vulnerable is_most_recent fever_chills_shakes cough  \
# 0       L4C        n          n              y                   n     n
# 1       P1H        y          y              y                   n     n
# 2       N2J        n          y              y                   n     n
# 3       N1G        n          n              y                   n     n
# 4       M1P        n          y              n                   n     n
# ...     ...      ...        ...            ...                 ...   ...
# 294100  M6P        n          n            NaN                   n     n
# 294101  K1R        n          n            NaN                   n     n
# 294102  M4M        n          n            NaN                   n     n
# 294103  M6P        n          y            NaN                   n     n
# 294104  K2H        n          n            NaN                   n     n
#
#        shortness_of_breath over_60 any_medical_conditions  \
# 0                        n       n                      n
# 1                        n       y                      y
# 2                        n       y                      n
# 3                        n       n                      n
# 4                        n       n                      y
# ...                    ...     ...                    ...
# 294100                   n     NaN                      y
# 294101                   n     NaN                      y
# 294102                   n     NaN                      y
# 294103                   n     NaN                      y
# 294104                   n     NaN                      y
#
#        travel_outside_canada  ... contact_in_household tested  \
# 0                          n  ...                  NaN    NaN
# 1                          n  ...                  NaN    NaN
# 2                          n  ...                  NaN    NaN
# 3                          n  ...                  NaN    NaN
# 4                          n  ...                  NaN    NaN
# ...                      ...  ...                  ...    ...
# 294100                     n  ...                  NaN      n
# 294101                     n  ...                  NaN      y
# 294102                     n  ...                  NaN      y
# 294103                     n  ...                  NaN      n
# 294104                     n  ...                  NaN      n
#
#        covid_results_date covid_positive mental_health_impact  \
# 0                     NaN            NaN                  NaN
# 1                     NaN            NaN                  NaN
# 2                     NaN            NaN                  NaN
# 3                     NaN            NaN                  NaN
# 4                     NaN            NaN                  NaN
# ...                   ...            ...                  ...
# 294100                NaN            NaN                  NaN
# 294101               July     negatively                  NaN
# 294102               July     negatively                  NaN
# 294103                NaN            NaN             noImpact
# 294104                NaN            NaN           negatively
#
#           travel_work_school self_isolating   media_channels  \
# 0                        NaN            NaN              NaN
# 1                        NaN            NaN              NaN
# 2                        NaN            NaN              NaN
# 3                        NaN            NaN              NaN
# 4                        NaN            NaN              NaN
# ...                      ...            ...              ...
# 294100                   NaN            NaN              NaN
# 294101                   NaN            NaN              NaN
# 294102                   NaN            NaN              NaN
# 294103     didntTravelBefore              n  newspaper;radio
# 294104  stillTravelEssential              y              NaN
#
#        financial_obligations_impact tobacco_usage
# 0                               NaN           NaN
# 1                               NaN           NaN
# 2                               NaN           NaN
# 3                               NaN           NaN
# 4                               NaN           NaN
# ...                             ...           ...
# 294100                          NaN           NaN
# 294101                          NaN           NaN
# 294102                          NaN           NaN
# 294103                          NaN             n
# 294104                          NaN             n
#
# [294105 rows x 28 columns]

# %%
final_df.columns
# Out:
# Index(['fsa', 'probable', 'vulnerable', 'is_most_recent',
#        'fever_chills_shakes', 'cough', 'shortness_of_breath', 'over_60',
#        'any_medical_conditions', 'travel_outside_canada',
#        'contact_with_illness', 'symptoms', 'conditions', 'ethnicity', 'sex',
#        'needs', 'age_1', 'month', 'contact_in_household', 'tested',
#        'covid_results_date', 'covid_positive', 'mental_health_impact',
#        'travel_work_school', 'self_isolating', 'media_channels',
#        'financial_obligations_impact', 'tobacco_usage'],
#       dtype='object')

# %%
final_df['age_1'] = final_df['over_60'].map({'y': '>65', 'n': '<65'})

# %%
final_df = final_df.drop(columns=['over_60'])

# %%
final_df#after dropping over 60 column
# Out:
#         fsa probable vulnerable is_most_recent fever_chills_shakes cough  \
# 0       L4C        n          n              y                   n     n
# 1       P1H        y          y              y                   n     n
# 2       N2J        n          y              y                   n     n
# 3       N1G        n          n              y                   n     n
# 4       M1P        n          y              n                   n     n
# ...     ...      ...        ...            ...                 ...   ...
# 294100  M6P        n          n            NaN                   n     n
# 294101  K1R        n          n            NaN                   n     n
# 294102  M4M        n          n            NaN                   n     n
# 294103  M6P        n          y            NaN                   n     n
# 294104  K2H        n          n            NaN                   n     n
#
#        shortness_of_breath any_medical_conditions travel_outside_canada  \
# 0                        n                      n                     n
# 1                        n                      y                     n
# 2                        n                      n                     n
# 3                        n                      n                     n
# 4                        n                      y                     n
# ...                    ...                    ...                   ...
# 294100                   n                      y                     n
# 294101                   n                      y                     n
# 294102                   n                      y                     n
# 294103                   n                      y                     n
# 294104                   n                      y                     n
#
#        contact_with_illness  ... contact_in_household tested  \
# 0                         n  ...                  NaN    NaN
# 1                         y  ...                  NaN    NaN
# 2                         n  ...                  NaN    NaN
# 3                         n  ...                  NaN    NaN
# 4                         n  ...                  NaN    NaN
# ...                     ...  ...                  ...    ...
# 294100                    n  ...                  NaN      n
# 294101                    n  ...                  NaN      y
# 294102                    n  ...                  NaN      y
# 294103                    n  ...                  NaN      n
# 294104                    n  ...                  NaN      n
#
#        covid_results_date covid_positive mental_health_impact  \
# 0                     NaN            NaN                  NaN
# 1                     NaN            NaN                  NaN
# 2                     NaN            NaN                  NaN
# 3                     NaN            NaN                  NaN
# 4                     NaN            NaN                  NaN
# ...                   ...            ...                  ...
# 294100                NaN            NaN                  NaN
# 294101               July     negatively                  NaN
# 294102               July     negatively                  NaN
# 294103                NaN            NaN             noImpact
# 294104                NaN            NaN           negatively
#
#           travel_work_school self_isolating   media_channels  \
# 0                        NaN            NaN              NaN
# 1                        NaN            NaN              NaN
# 2                        NaN            NaN              NaN
# 3                        NaN            NaN              NaN
# 4                        NaN            NaN              NaN
# ...                      ...            ...              ...
# 294100                   NaN            NaN              NaN
# 294101                   NaN            NaN              NaN
# 294102                   NaN            NaN              NaN
# 294103     didntTravelBefore              n  newspaper;radio
# 294104  stillTravelEssential              y              NaN
#
#        financial_obligations_impact tobacco_usage
# 0                               NaN           NaN
# 1                               NaN           NaN
# 2                               NaN           NaN
# 3                               NaN           NaN
# 4                               NaN           NaN
# ...                             ...           ...
# 294100                          NaN           NaN
# 294101                          NaN           NaN
# 294102                          NaN           NaN
# 294103                          NaN             n
# 294104                          NaN             n
#
# [294105 rows x 27 columns]

# %%
binary_cols = [
    'probable', 'vulnerable', 'is_most_recent',
       'fever_chills_shakes', 'cough', 'shortness_of_breath',
       'any_medical_conditions', 'travel_outside_canada',
       'contact_with_illness', 'contact_in_household',
       'tested', ]

for col in binary_cols:
    if col in final_df.columns:
      final_df[col] = final_df[col].map({'y': 1, 'n': 0}).fillna(0).astype(int)

# %%
   final_df# changing y to '0" and N to 1
# Out:
#         fsa  probable  vulnerable  is_most_recent  fever_chills_shakes  cough  \
# 0       L4C         0           0               1                    0      0
# 1       P1H         1           1               1                    0      0
# 2       N2J         0           1               1                    0      0
# 3       N1G         0           0               1                    0      0
# 4       M1P         0           1               0                    0      0
# ...     ...       ...         ...             ...                  ...    ...
# 294100  M6P         0           0               0                    0      0
# 294101  K1R         0           0               0                    0      0
# 294102  M4M         0           0               0                    0      0
# 294103  M6P         0           1               0                    0      0
# 294104  K2H         0           0               0                    0      0
#
#         shortness_of_breath  any_medical_conditions  travel_outside_canada  \
# 0                         0                       0                      0
# 1                         0                       1                      0
# 2                         0                       0                      0
# 3                         0                       0                      0
# 4                         0                       1                      0
# ...                     ...                     ...                    ...
# 294100                    0                       1                      0
# 294101                    0                       1                      0
# 294102                    0                       1                      0
# 294103                    0                       1                      0
# 294104                    0                       1                      0
#
#         contact_with_illness  ... contact_in_household tested  \
# 0                          0  ...                    0      0
# 1                          1  ...                    0      0
# 2                          0  ...                    0      0
# 3                          0  ...                    0      0
# 4                          0  ...                    0      0
# ...                      ...  ...                  ...    ...
# 294100                     0  ...                    0      0
# 294101                     0  ...                    0      1
# 294102                     0  ...                    0      1
# 294103                     0  ...                    0      0
# 294104                     0  ...                    0      0
#
#        covid_results_date covid_positive mental_health_impact  \
# 0                     NaN            NaN                  NaN
# 1                     NaN            NaN                  NaN
# 2                     NaN            NaN                  NaN
# 3                     NaN            NaN                  NaN
# 4                     NaN            NaN                  NaN
# ...                   ...            ...                  ...
# 294100                NaN            NaN                  NaN
# 294101               July     negatively                  NaN
# 294102               July     negatively                  NaN
# 294103                NaN            NaN             noImpact
# 294104                NaN            NaN           negatively
#
#           travel_work_school self_isolating   media_channels  \
# 0                        NaN            NaN              NaN
# 1                        NaN            NaN              NaN
# 2                        NaN            NaN              NaN
# 3                        NaN            NaN              NaN
# 4                        NaN            NaN              NaN
# ...                      ...            ...              ...
# 294100                   NaN            NaN              NaN
# 294101                   NaN            NaN              NaN
# 294102                   NaN            NaN              NaN
# 294103     didntTravelBefore              n  newspaper;radio
# 294104  stillTravelEssential              y              NaN
#
#         financial_obligations_impact tobacco_usage
# 0                                NaN           NaN
# 1                                NaN           NaN
# 2                                NaN           NaN
# 3                                NaN           NaN
# 4                                NaN           NaN
# ...                              ...           ...
# 294100                           NaN           NaN
# 294101                           NaN           NaN
# 294102                           NaN           NaN
# 294103                           NaN             n
# 294104                           NaN             n
#
# [294105 rows x 27 columns]

# %%
cols = ['month'] + [c for c in final_df.columns if c != 'month']
final_df = final_df[cols]
final_df #moving month to front
# Out:
#         month  fsa  probable  vulnerable  is_most_recent  fever_chills_shakes  \
# 0       April  L4C         0           0               1                    0
# 1       April  P1H         1           1               1                    0
# 2       April  N2J         0           1               1                    0
# 3       April  N1G         0           0               1                    0
# 4       April  M1P         0           1               0                    0
# ...       ...  ...       ...         ...             ...                  ...
# 294100   July  M6P         0           0               0                    0
# 294101   July  K1R         0           0               0                    0
# 294102   July  M4M         0           0               0                    0
# 294103   July  M6P         0           1               0                    0
# 294104   July  K2H         0           0               0                    0
#
#         cough  shortness_of_breath  any_medical_conditions  \
# 0           0                    0                       0
# 1           0                    0                       1
# 2           0                    0                       0
# 3           0                    0                       0
# 4           0                    0                       1
# ...       ...                  ...                     ...
# 294100      0                    0                       1
# 294101      0                    0                       1
# 294102      0                    0                       1
# 294103      0                    0                       1
# 294104      0                    0                       1
#
#         travel_outside_canada  ...  contact_in_household tested  \
# 0                           0  ...                     0      0
# 1                           0  ...                     0      0
# 2                           0  ...                     0      0
# 3                           0  ...                     0      0
# 4                           0  ...                     0      0
# ...                       ...  ...                   ...    ...
# 294100                      0  ...                     0      0
# 294101                      0  ...                     0      1
# 294102                      0  ...                     0      1
# 294103                      0  ...                     0      0
# 294104                      0  ...                     0      0
#
#        covid_results_date covid_positive mental_health_impact  \
# 0                     NaN            NaN                  NaN
# 1                     NaN            NaN                  NaN
# 2                     NaN            NaN                  NaN
# 3                     NaN            NaN                  NaN
# 4                     NaN            NaN                  NaN
# ...                   ...            ...                  ...
# 294100                NaN            NaN                  NaN
# 294101               July     negatively                  NaN
# 294102               July     negatively                  NaN
# 294103                NaN            NaN             noImpact
# 294104                NaN            NaN           negatively
#
#           travel_work_school self_isolating   media_channels  \
# 0                        NaN            NaN              NaN
# 1                        NaN            NaN              NaN
# 2                        NaN            NaN              NaN
# 3                        NaN            NaN              NaN
# 4                        NaN            NaN              NaN
# ...                      ...            ...              ...
# 294100                   NaN            NaN              NaN
# 294101                   NaN            NaN              NaN
# 294102                   NaN            NaN              NaN
# 294103     didntTravelBefore              n  newspaper;radio
# 294104  stillTravelEssential              y              NaN
#
#         financial_obligations_impact tobacco_usage
# 0                                NaN           NaN
# 1                                NaN           NaN
# 2                                NaN           NaN
# 3                                NaN           NaN
# 4                                NaN           NaN
# ...                              ...           ...
# 294100                           NaN           NaN
# 294101                           NaN           NaN
# 294102                           NaN           NaN
# 294103                           NaN             n
# 294104                           NaN             n
#
# [294105 rows x 27 columns]

# %%
text_cols = ['symptoms', 'conditions', 'ethnicity', 'needs']

# Fill NaNs with 'none' to represent a negative or neutral response
for col in text_cols:
    if col in final_df.columns:
       final_df[col] = final_df[col].fillna('none')

# %%
final_df["symptoms"]
# Out:
# 0         none
# 1         none
# 2         none
# 3         none
# 4         none
#           ...
# 294100    none
# 294101    none
# 294102    none
# 294103    none
# 294104    none
# Name: symptoms, Length: 294105, dtype: object

# %%
final_df.isnull().sum()
# Out:
# month                                0
# fsa                                  0
# probable                             0
# vulnerable                           0
# is_most_recent                       0
# fever_chills_shakes                  0
# cough                                0
# shortness_of_breath                  0
# any_medical_conditions               0
# travel_outside_canada                0
# contact_with_illness                 0
# symptoms                             0
# conditions                           0
# ethnicity                            0
# sex                             270491
# needs                                0
# age_1                            30466
# contact_in_household                 0
# tested                               0
# covid_results_date              293684
# covid_positive                  293615
# mental_health_impact            285418
# travel_work_school              285425
# self_isolating                  285426
# media_channels                  288403
# financial_obligations_impact    293189
# tobacco_usage                   285427
# dtype: int64

# %%
print(final_df[['month', 'age_1', 'cough', 'ethnicity']].isnull().sum())
# Out:
# month            0
# age_1        30466
# cough            0
# ethnicity        0
# dtype: int64

# %%
# 1. Define groups for different filling strategies
none_fill_cols = [
    'needs', 'mental_health_impact', 'travel_work_school', 
    'self_isolating', 'media_channels', 'financial_obligations_impact', 
    'tobacco_usage'
]

unknown_fill_cols = ['sex', 'age_1']

# 2. Apply the fills
# Fill behavioral/impact columns with 'none'
for col in none_fill_cols:
    if col in final_df.columns:
      final_df[col] = final_df[col].fillna('none')

# Fill demographic columns with 'unknown'
for col in unknown_fill_cols:
    if col in final_df.columns:
       final_df[col] = final_df[col].fillna('unknown')

# %%
final_df
# Out:
#         month  fsa  probable  vulnerable  is_most_recent  fever_chills_shakes  \
# 0       April  L4C         0           0               1                    0
# 1       April  P1H         1           1               1                    0
# 2       April  N2J         0           1               1                    0
# 3       April  N1G         0           0               1                    0
# 4       April  M1P         0           1               0                    0
# ...       ...  ...       ...         ...             ...                  ...
# 294100   July  M6P         0           0               0                    0
# 294101   July  K1R         0           0               0                    0
# 294102   July  M4M         0           0               0                    0
# 294103   July  M6P         0           1               0                    0
# 294104   July  K2H         0           0               0                    0
#
#         cough  shortness_of_breath  any_medical_conditions  \
# 0           0                    0                       0
# 1           0                    0                       1
# 2           0                    0                       0
# 3           0                    0                       0
# 4           0                    0                       1
# ...       ...                  ...                     ...
# 294100      0                    0                       1
# 294101      0                    0                       1
# 294102      0                    0                       1
# 294103      0                    0                       1
# 294104      0                    0                       1
#
#         travel_outside_canada  ...  contact_in_household tested  \
# 0                           0  ...                     0      0
# 1                           0  ...                     0      0
# 2                           0  ...                     0      0
# 3                           0  ...                     0      0
# 4                           0  ...                     0      0
# ...                       ...  ...                   ...    ...
# 294100                      0  ...                     0      0
# 294101                      0  ...                     0      1
# 294102                      0  ...                     0      1
# 294103                      0  ...                     0      0
# 294104                      0  ...                     0      0
#
#        covid_results_date covid_positive mental_health_impact  \
# 0                     NaN            NaN                 none
# 1                     NaN            NaN                 none
# 2                     NaN            NaN                 none
# 3                     NaN            NaN                 none
# 4                     NaN            NaN                 none
# ...                   ...            ...                  ...
# 294100                NaN            NaN                 none
# 294101               July     negatively                 none
# 294102               July     negatively                 none
# 294103                NaN            NaN             noImpact
# 294104                NaN            NaN           negatively
#
#           travel_work_school self_isolating   media_channels  \
# 0                       none           none             none
# 1                       none           none             none
# 2                       none           none             none
# 3                       none           none             none
# 4                       none           none             none
# ...                      ...            ...              ...
# 294100                  none           none             none
# 294101                  none           none             none
# 294102                  none           none             none
# 294103     didntTravelBefore              n  newspaper;radio
# 294104  stillTravelEssential              y             none
#
#         financial_obligations_impact tobacco_usage
# 0                               none          none
# 1                               none          none
# 2                               none          none
# 3                               none          none
# 4                               none          none
# ...                              ...           ...
# 294100                          none          none
# 294101                          none          none
# 294102                          none          none
# 294103                          none             n
# 294104                          none             n
#
# [294105 rows x 27 columns]

# %%
# 1. Fill NaN values with 'none' first (very important!)
final_df['symptoms'] = final_df['symptoms'].fillna('none')

# 2. Split the semicolon-separated strings into a matrix of 1s and 0s
symptom_dummies = final_df['symptoms'].str.get_dummies(sep=';')

# 3. Combine this new matrix with your original dataset
# We prefix the columns with 'symp_' so we know where they came from
symptom_dummies = symptom_dummies.add_prefix('symp_')
df_final = pd.concat([final_df, symptom_dummies], axis=1)

# 4. Optional: Drop the original text column to save space
df_final = final_df.drop(columns=['symptoms'])

# %%
df_final #final cleaned data
# Out:
#         month  fsa  probable  vulnerable  is_most_recent  fever_chills_shakes  \
# 0       April  L4C         0           0               1                    0
# 1       April  P1H         1           1               1                    0
# 2       April  N2J         0           1               1                    0
# 3       April  N1G         0           0               1                    0
# 4       April  M1P         0           1               0                    0
# ...       ...  ...       ...         ...             ...                  ...
# 294100   July  M6P         0           0               0                    0
# 294101   July  K1R         0           0               0                    0
# 294102   July  M4M         0           0               0                    0
# 294103   July  M6P         0           1               0                    0
# 294104   July  K2H         0           0               0                    0
#
#         cough  shortness_of_breath  any_medical_conditions  \
# 0           0                    0                       0
# 1           0                    0                       1
# 2           0                    0                       0
# 3           0                    0                       0
# 4           0                    0                       1
# ...       ...                  ...                     ...
# 294100      0                    0                       1
# 294101      0                    0                       1
# 294102      0                    0                       1
# 294103      0                    0                       1
# 294104      0                    0                       1
#
#         travel_outside_canada  ...  contact_in_household tested  \
# 0                           0  ...                     0      0
# 1                           0  ...                     0      0
# 2                           0  ...                     0      0
# 3                           0  ...                     0      0
# 4                           0  ...                     0      0
# ...                       ...  ...                   ...    ...
# 294100                      0  ...                     0      0
# 294101                      0  ...                     0      1
# 294102                      0  ...                     0      1
# 294103                      0  ...                     0      0
# 294104                      0  ...                     0      0
#
#        covid_results_date covid_positive mental_health_impact  \
# 0                     NaN            NaN                 none
# 1                     NaN            NaN                 none
# 2                     NaN            NaN                 none
# 3                     NaN            NaN                 none
# 4                     NaN            NaN                 none
# ...                   ...            ...                  ...
# 294100                NaN            NaN                 none
# 294101               July     negatively                 none
# 294102               July     negatively                 none
# 294103                NaN            NaN             noImpact
# 294104                NaN            NaN           negatively
#
#           travel_work_school  self_isolating   media_channels  \
# 0                       none            none             none
# 1                       none            none             none
# 2                       none            none             none
# 3                       none            none             none
# 4                       none            none             none
# ...                      ...             ...              ...
# 294100                  none            none             none
# 294101                  none            none             none
# 294102                  none            none             none
# 294103     didntTravelBefore               n  newspaper;radio
# 294104  stillTravelEssential               y             none
#
#        financial_obligations_impact tobacco_usage
# 0                              none          none
# 1                              none          none
# 2                              none          none
# 3                              none          none
# 4                              none          none
# ...                             ...           ...
# 294100                         none          none
# 294101                         none          none
# 294102                         none          none
# 294103                         none             n
# 294104                         none             n
#
# [294105 rows x 26 columns]
