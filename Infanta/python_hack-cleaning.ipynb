# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import os
os.getcwd()
# Out:
# 'C:\\Users\\ajaya'

# %%
schema_1 = pd.read_csv(r"C:\Users\ajaya\Desktop\NUMPYNINJA\HACKATHON\HACKATHON DETAILS\schema_1_ontario_final.csv")
schema_2 = pd.read_csv(r"C:\Users\ajaya\Desktop\NUMPYNINJA\HACKATHON\HACKATHON DETAILS\schema_2_ontario_final.csv")
schema_3 = pd.read_csv(r"C:\Users\ajaya\Desktop\NUMPYNINJA\HACKATHON\HACKATHON DETAILS\schema_3_ontario_final.csv")

# %%
schema_1 #Reading Schema 1 file
# Out:
#         week  fsa probable vulnerable is_most_recent fever_chills_shakes  \
# 0         13  L4C        n          n              y                   n
# 1         13  P1H        y          y              y                   n
# 2         14  N2J        n          y              y                   n
# 3         13  N1G        n          n              y                   n
# 4         13  M1P        n          y              n                   n
# ...      ...  ...      ...        ...            ...                 ...
# 263634    14  N0G        n          y              y                   n
# 263635    14  M6P        n          y              y                   n
# 263636    13  L3X        n          n              y                   n
# 263637    14  M6R        n          n              y                   n
# 263638    13  M8V        y          y              y                   n
#
#        cough shortness_of_breath over_60 any_medical_conditions  \
# 0          n                   n       n                      n
# 1          n                   n       y                      y
# 2          n                   n       y                      n
# 3          n                   n       n                      n
# 4          n                   n       n                      y
# ...      ...                 ...     ...                    ...
# 263634     n                   n       n                      y
# 263635     n                   n       n                      y
# 263636     n                   n       n                      n
# 263637     n                   n       n                      n
# 263638     n                   n       y                      n
#
#        travel_outside_canada contact_with_illness
# 0                          n                    n
# 1                          n                    y
# 2                          n                    n
# 3                          n                    n
# 4                          n                    n
# ...                      ...                  ...
# 263634                     n                    n
# 263635                     n                    n
# 263636                     n                    n
# 263637                     n                    n
# 263638                     y                    y
#
# [263639 rows x 12 columns]

# %%
schema_2#Reading Schema 2 file
# Out:
#        week  fsa probable vulnerable is_most_recent fever_chills_shakes cough  \
# 0        15  M1P        n          n              y                   n     n
# 1        16  N2P        n          y              y                   n     n
# 2        16  N2P        n          y              n                   n     n
# 3        16  M4P        n          n              y                   n     n
# 4        16  L4N        n          n              y                   n     n
# ...     ...  ...      ...        ...            ...                 ...   ...
# 14927    15  L6B        n          y              y                   n     n
# 14928    15  L6J        n          n              y                   n     n
# 14929    16  N9V        n          n              y                   n     n
# 14930    16  L3Z        n          n              y                   n     n
# 14931    16  L6J        n          n              y                   n     n
#
#       shortness_of_breath any_medical_conditions travel_outside_canada  \
# 0                       n                      y                     n
# 1                       n                      y                     n
# 2                       n                      y                     n
# 3                       n                      y                     n
# 4                       n                      y                     n
# ...                   ...                    ...                   ...
# 14927                   n                      y                     n
# 14928                   n                      y                     n
# 14929                   n                      y                     n
# 14930                   n                      y                     n
# 14931                   n                      y                     n
#
#       contact_with_illness   symptoms                      conditions  \
# 0                        n        NaN                             NaN
# 1                        n  runnyNose               highBloodPressure
# 2                        n        NaN               highBloodPressure
# 3                        n        NaN                             NaN
# 4                        n        NaN                             NaN
# ...                    ...        ...                             ...
# 14927                    n        NaN  heartDisease;breathingProblems
# 14928                    n  runnyNose                             NaN
# 14929                    n        NaN                             NaN
# 14930                    n        NaN                             NaN
# 14931                    n        NaN                             NaN
#
#        ethnicity sex             needs  age_1
# 0            NaN   m               NaN  45-64
# 1          asian   m             other  45-64
# 2          asian   m             other  45-64
# 3      caucasian   f  emotionalSupport  26-44
# 4      caucasian   f  emotionalSupport  26-44
# ...          ...  ..               ...    ...
# 14927        NaN   f               NaN  26-44
# 14928        NaN   f               NaN  45-64
# 14929  caucasian   m             other  26-44
# 14930      asian   m             other  26-44
# 14931  caucasian   m             other  26-44
#
# [14932 rows x 17 columns]

# %%
schema_3#Reading Schema 3 file
# Out:
#        month  fsa probable vulnerable fever_chills_shakes cough  \
# 0      April  M4P        n          n                   n     n
# 1      April  M9P        n          n                   n     n
# 2      April  K0L        n          n                   n     n
# 3      April  N9E        n          n                   n     n
# 4      April  L2N        n          n                   n     n
# ...      ...  ...      ...        ...                 ...   ...
# 15529   July  M6P        n          n                   n     n
# 15530   July  K1R        n          n                   n     n
# 15531   July  M4M        n          n                   n     n
# 15532   July  M6P        n          y                   n     n
# 15533   July  K2H        n          n                   n     n
#
#       shortness_of_breath any_medical_conditions travel_outside_canada  \
# 0                       n                      y                     n
# 1                       n                      y                     n
# 2                       n                      y                     n
# 3                       n                      y                     n
# 4                       n                      y                     n
# ...                   ...                    ...                   ...
# 15529                   n                      y                     n
# 15530                   n                      y                     n
# 15531                   n                      y                     n
# 15532                   n                      y                     n
# 15533                   n                      y                     n
#
#       contact_with_illness  ...                             ethnicity  sex  \
# 0                        n  ...                                   NaN  NaN
# 1                        n  ...                             caucasian    f
# 2                        n  ...                                   NaN  NaN
# 3                        n  ...                                   NaN  NaN
# 4                        n  ...                                   NaN  NaN
# ...                    ...  ...                                   ...  ...
# 15529                    n  ...                                   NaN  NaN
# 15530                    n  ...  firstNations;black/african;caucasian  NaN
# 15531                    n  ...                                   NaN  NaN
# 15532                    n  ...                                   NaN    m
# 15533                    n  ...                                   NaN    f
#
#                   needs  age_1 mental_health_impact    travel_work_school  \
# 0        noneOfTheAbove    <26                  NaN                   NaN
# 1                  food    <26             noImpact     stoppedTravelling
# 2        noneOfTheAbove  45-64                  NaN                   NaN
# 3        noneOfTheAbove  45-64                  NaN                   NaN
# 4      financialSupport    <26                  NaN                   NaN
# ...                 ...    ...                  ...                   ...
# 15529  emotionalSupport  45-64                  NaN                   NaN
# 15530  emotionalSupport  26-44                  NaN                   NaN
# 15531    noneOfTheAbove  26-44                  NaN                   NaN
# 15532    noneOfTheAbove    >65             noImpact     didntTravelBefore
# 15533    noneOfTheAbove  45-64           negatively  stillTravelEssential
#
#       self_isolating     media_channels financial_obligations_impact  \
# 0                NaN                NaN                          NaN
# 1                  y  twitter;tv;reddit                          NaN
# 2                NaN                NaN                          NaN
# 3                NaN                NaN                          NaN
# 4                NaN                NaN                          NaN
# ...              ...                ...                          ...
# 15529            NaN                NaN                          NaN
# 15530            NaN                NaN                          NaN
# 15531            NaN                NaN                          NaN
# 15532              n    newspaper;radio                          NaN
# 15533              y                NaN                          NaN
#
#       tobacco_usage
# 0               NaN
# 1                 n
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 15529           NaN
# 15530           NaN
# 15531           NaN
# 15532             n
# 15533             n
#
# [15534 rows x 26 columns]

# %%
schema_1.columns
# Out:
# Index(['week', 'fsa', 'probable', 'vulnerable', 'is_most_recent',
#        'fever_chills_shakes', 'cough', 'shortness_of_breath', 'over_60',
#        'any_medical_conditions', 'travel_outside_canada',
#        'contact_with_illness'],
#       dtype='object')

# %%
schema_2.columns
# Out:
# Index(['week', 'fsa', 'probable', 'vulnerable', 'is_most_recent',
#        'fever_chills_shakes', 'cough', 'shortness_of_breath',
#        'any_medical_conditions', 'travel_outside_canada',
#        'contact_with_illness', 'symptoms', 'conditions', 'ethnicity', 'sex',
#        'needs', 'age_1'],
#       dtype='object')

# %%
schema_3.columns
# Out:
# Index(['month', 'fsa', 'probable', 'vulnerable', 'fever_chills_shakes',
#        'cough', 'shortness_of_breath', 'any_medical_conditions',
#        'travel_outside_canada', 'contact_with_illness', 'contact_in_household',
#        'tested', 'covid_results_date', 'covid_positive', 'symptoms',
#        'conditions', 'ethnicity', 'sex', 'needs', 'age_1',
#        'mental_health_impact', 'travel_work_school', 'self_isolating',
#        'media_channels', 'financial_obligations_impact', 'tobacco_usage'],
#       dtype='object')

# %%
combined_schema_df = pd.concat([schema_1, schema_2,schema_3], ignore_index=True, sort=False)  #combining 3 file

# %%
combined_schema_df
# Out:
#         week  fsa probable vulnerable is_most_recent fever_chills_shakes  \
# 0       13.0  L4C        n          n              y                   n
# 1       13.0  P1H        y          y              y                   n
# 2       14.0  N2J        n          y              y                   n
# 3       13.0  N1G        n          n              y                   n
# 4       13.0  M1P        n          y              n                   n
# ...      ...  ...      ...        ...            ...                 ...
# 294100   NaN  M6P        n          n            NaN                   n
# 294101   NaN  K1R        n          n            NaN                   n
# 294102   NaN  M4M        n          n            NaN                   n
# 294103   NaN  M6P        n          y            NaN                   n
# 294104   NaN  K2H        n          n            NaN                   n
#
#        cough shortness_of_breath over_60 any_medical_conditions  ...  \
# 0          n                   n       n                      n  ...
# 1          n                   n       y                      y  ...
# 2          n                   n       y                      n  ...
# 3          n                   n       n                      n  ...
# 4          n                   n       n                      y  ...
# ...      ...                 ...     ...                    ...  ...
# 294100     n                   n     NaN                      y  ...
# 294101     n                   n     NaN                      y  ...
# 294102     n                   n     NaN                      y  ...
# 294103     n                   n     NaN                      y  ...
# 294104     n                   n     NaN                      y  ...
#
#        contact_in_household tested covid_results_date covid_positive  \
# 0                       NaN    NaN                NaN            NaN
# 1                       NaN    NaN                NaN            NaN
# 2                       NaN    NaN                NaN            NaN
# 3                       NaN    NaN                NaN            NaN
# 4                       NaN    NaN                NaN            NaN
# ...                     ...    ...                ...            ...
# 294100                  NaN      n                NaN            NaN
# 294101                  NaN      y               July     negatively
# 294102                  NaN      y               July     negatively
# 294103                  NaN      n                NaN            NaN
# 294104                  NaN      n                NaN            NaN
#
#        mental_health_impact    travel_work_school self_isolating  \
# 0                       NaN                   NaN            NaN
# 1                       NaN                   NaN            NaN
# 2                       NaN                   NaN            NaN
# 3                       NaN                   NaN            NaN
# 4                       NaN                   NaN            NaN
# ...                     ...                   ...            ...
# 294100                  NaN                   NaN            NaN
# 294101                  NaN                   NaN            NaN
# 294102                  NaN                   NaN            NaN
# 294103             noImpact     didntTravelBefore              n
# 294104           negatively  stillTravelEssential              y
#
#          media_channels financial_obligations_impact tobacco_usage
# 0                   NaN                          NaN           NaN
# 1                   NaN                          NaN           NaN
# 2                   NaN                          NaN           NaN
# 3                   NaN                          NaN           NaN
# 4                   NaN                          NaN           NaN
# ...                 ...                          ...           ...
# 294100              NaN                          NaN           NaN
# 294101              NaN                          NaN           NaN
# 294102              NaN                          NaN           NaN
# 294103  newspaper;radio                          NaN             n
# 294104              NaN                          NaN             n
#
# [294105 rows x 29 columns]

# %%
combined_schema_df.columns
# Out:
# Index(['week', 'fsa', 'probable', 'vulnerable', 'is_most_recent',
#        'fever_chills_shakes', 'cough', 'shortness_of_breath', 'over_60',
#        'any_medical_conditions', 'travel_outside_canada',
#        'contact_with_illness', 'symptoms', 'conditions', 'ethnicity', 'sex',
#        'needs', 'age_1', 'month', 'contact_in_household', 'tested',
#        'covid_results_date', 'covid_positive', 'mental_health_impact',
#        'travel_work_school', 'self_isolating', 'media_channels',
#        'financial_obligations_impact', 'tobacco_usage'],
#       dtype='object')

# %%
combined_schema_df.info()#non -null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294105 entries, 0 to 294104
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   week                          278571 non-null  float64
#  1   fsa                           294105 non-null  object
#  2   probable                      294105 non-null  object
#  3   vulnerable                    294105 non-null  object
#  4   is_most_recent                278571 non-null  object
#  5   fever_chills_shakes           294105 non-null  object
#  6   cough                         294105 non-null  object
#  7   shortness_of_breath           294105 non-null  object
#  8   over_60                       263639 non-null  object
#  9   any_medical_conditions        294105 non-null  object
#  10  travel_outside_canada         294105 non-null  object
#  11  contact_with_illness          294105 non-null  object
#  12  symptoms                      2589 non-null    object
#  13  conditions                    6157 non-null    object
#  14  ethnicity                     7399 non-null    object
#  15  sex                           23614 non-null   object
#  16  needs                         22635 non-null   object
#  17  age_1                         30466 non-null   object
#  18  month                         15534 non-null   object
#  19  contact_in_household          159 non-null     object
#  20  tested                        15534 non-null   object
#  21  covid_results_date            421 non-null     object
#  22  covid_positive                490 non-null     object
#  23  mental_health_impact          8687 non-null    object
#  24  travel_work_school            8680 non-null    object
#  25  self_isolating                8679 non-null    object
#  26  media_channels                5702 non-null    object
#  27  financial_obligations_impact  916 non-null     object
#  28  tobacco_usage                 8678 non-null    object
# dtypes: float64(1), object(28)
# memory usage: 65.1+ MB

# %%
combined_schema_df.isna().sum() #null values count
# Out:
# week                             15534
# fsa                                  0
# probable                             0
# vulnerable                           0
# is_most_recent                   15534
# fever_chills_shakes                  0
# cough                                0
# shortness_of_breath                  0
# over_60                          30466
# any_medical_conditions               0
# travel_outside_canada                0
# contact_with_illness                 0
# symptoms                        291516
# conditions                      287948
# ethnicity                       286706
# sex                             270491
# needs                           271470
# age_1                           263639
# month                           278571
# contact_in_household            293946
# tested                          278571
# covid_results_date              293684
# covid_positive                  293615
# mental_health_impact            285418
# travel_work_school              285425
# self_isolating                  285426
# media_channels                  288403
# financial_obligations_impact    293189
# tobacco_usage                   285427
# dtype: int64

# %%
combined_schema_df.loc[combined_schema_df['week'].isna()] #weekwise null value
# Out:
#         week  fsa probable vulnerable is_most_recent fever_chills_shakes  \
# 278571   NaN  M4P        n          n            NaN                   n
# 278572   NaN  M9P        n          n            NaN                   n
# 278573   NaN  K0L        n          n            NaN                   n
# 278574   NaN  N9E        n          n            NaN                   n
# 278575   NaN  L2N        n          n            NaN                   n
# ...      ...  ...      ...        ...            ...                 ...
# 294100   NaN  M6P        n          n            NaN                   n
# 294101   NaN  K1R        n          n            NaN                   n
# 294102   NaN  M4M        n          n            NaN                   n
# 294103   NaN  M6P        n          y            NaN                   n
# 294104   NaN  K2H        n          n            NaN                   n
#
#        cough shortness_of_breath over_60 any_medical_conditions  ...  \
# 278571     n                   n     NaN                      y  ...
# 278572     n                   n     NaN                      y  ...
# 278573     n                   n     NaN                      y  ...
# 278574     n                   n     NaN                      y  ...
# 278575     n                   n     NaN                      y  ...
# ...      ...                 ...     ...                    ...  ...
# 294100     n                   n     NaN                      y  ...
# 294101     n                   n     NaN                      y  ...
# 294102     n                   n     NaN                      y  ...
# 294103     n                   n     NaN                      y  ...
# 294104     n                   n     NaN                      y  ...
#
#        contact_in_household tested covid_results_date covid_positive  \
# 278571                  NaN      n                NaN            NaN
# 278572                  NaN      n                NaN            NaN
# 278573                  NaN      n                NaN            NaN
# 278574                  NaN      n                NaN            NaN
# 278575                  NaN      n                NaN            NaN
# ...                     ...    ...                ...            ...
# 294100                  NaN      n                NaN            NaN
# 294101                  NaN      y               July     negatively
# 294102                  NaN      y               July     negatively
# 294103                  NaN      n                NaN            NaN
# 294104                  NaN      n                NaN            NaN
#
#        mental_health_impact    travel_work_school self_isolating  \
# 278571                  NaN                   NaN            NaN
# 278572             noImpact     stoppedTravelling              y
# 278573                  NaN                   NaN            NaN
# 278574                  NaN                   NaN            NaN
# 278575                  NaN                   NaN            NaN
# ...                     ...                   ...            ...
# 294100                  NaN                   NaN            NaN
# 294101                  NaN                   NaN            NaN
# 294102                  NaN                   NaN            NaN
# 294103             noImpact     didntTravelBefore              n
# 294104           negatively  stillTravelEssential              y
#
#            media_channels financial_obligations_impact tobacco_usage
# 278571                NaN                          NaN           NaN
# 278572  twitter;tv;reddit                          NaN             n
# 278573                NaN                          NaN           NaN
# 278574                NaN                          NaN           NaN
# 278575                NaN                          NaN           NaN
# ...                   ...                          ...           ...
# 294100                NaN                          NaN           NaN
# 294101                NaN                          NaN           NaN
# 294102                NaN                          NaN           NaN
# 294103    newspaper;radio                          NaN             n
# 294104                NaN                          NaN             n
#
# [15534 rows x 29 columns]

# %%
combined_schema_df[combined_schema_df.duplicated()] 3duplicated
# Out:
#         week  fsa probable vulnerable is_most_recent fever_chills_shakes  \
# 86      13.0  M4L        n          n              y                   n
# 91      13.0  L1M        n          y              n                   n
# 94      14.0  L7E        n          n              y                   n
# 107     13.0  L3C        n          n              y                   n
# 125     13.0  L4C        n          n              y                   n
# ...      ...  ...      ...        ...            ...                 ...
# 294089   NaN  L9W        n          n            NaN                   n
# 294092   NaN  M6P        n          n            NaN                   n
# 294095   NaN  M4E        n          n            NaN                   n
# 294099   NaN  L9W        n          n            NaN                   n
# 294100   NaN  M6P        n          n            NaN                   n
#
#        cough shortness_of_breath over_60 any_medical_conditions  ...  \
# 86         n                   n       n                      n  ...
# 91         n                   n       y                      n  ...
# 94         n                   n       n                      n  ...
# 107        n                   n       n                      n  ...
# 125        n                   n       n                      n  ...
# ...      ...                 ...     ...                    ...  ...
# 294089     n                   n     NaN                      y  ...
# 294092     n                   n     NaN                      y  ...
# 294095     n                   n     NaN                      y  ...
# 294099     n                   n     NaN                      y  ...
# 294100     n                   n     NaN                      y  ...
#
#        contact_in_household tested covid_results_date covid_positive  \
# 86                      NaN    NaN                NaN            NaN
# 91                      NaN    NaN                NaN            NaN
# 94                      NaN    NaN                NaN            NaN
# 107                     NaN    NaN                NaN            NaN
# 125                     NaN    NaN                NaN            NaN
# ...                     ...    ...                ...            ...
# 294089                  NaN      n                NaN            NaN
# 294092                  NaN      n                NaN            NaN
# 294095                  NaN      n                NaN            NaN
# 294099                  NaN      n                NaN            NaN
# 294100                  NaN      n                NaN            NaN
#
#        mental_health_impact travel_work_school self_isolating media_channels  \
# 86                      NaN                NaN            NaN            NaN
# 91                      NaN                NaN            NaN            NaN
# 94                      NaN                NaN            NaN            NaN
# 107                     NaN                NaN            NaN            NaN
# 125                     NaN                NaN            NaN            NaN
# ...                     ...                ...            ...            ...
# 294089                  NaN                NaN            NaN            NaN
# 294092                  NaN                NaN            NaN            NaN
# 294095                  NaN                NaN            NaN            NaN
# 294099                  NaN                NaN            NaN            NaN
# 294100                  NaN                NaN            NaN            NaN
#
#        financial_obligations_impact tobacco_usage
# 86                              NaN           NaN
# 91                              NaN           NaN
# 94                              NaN           NaN
# 107                             NaN           NaN
# 125                             NaN           NaN
# ...                             ...           ...
# 294089                          NaN           NaN
# 294092                          NaN           NaN
# 294095                          NaN           NaN
# 294099                          NaN           NaN
# 294100                          NaN           NaN
#
# [248160 rows x 29 columns]
