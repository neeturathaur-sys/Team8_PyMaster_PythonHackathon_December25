# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\varle\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\varle\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\varle\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\varle\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\varle\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\varle\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %% [markdown]
# import numpy as np

# %% [markdown]
# load the data

# %%
df3 = pd.read_csv(
    "C:\\Users\\varle\\Downloads\\Python heackathon Data\\schema_3_ontario_final.csv"
)

df3.head()
# Out:
#    month  fsa probable vulnerable fever_chills_shakes cough  \
# 0  April  M4P        n          n                   n     n
# 1  April  M9P        n          n                   n     n
# 2  April  K0L        n          n                   n     n
# 3  April  N9E        n          n                   n     n
# 4  April  L2N        n          n                   n     n
#
#   shortness_of_breath any_medical_conditions travel_outside_canada  \
# 0                   n                      y                     n
# 1                   n                      y                     n
# 2                   n                      y                     n
# 3                   n                      y                     n
# 4                   n                      y                     n
#
#   contact_with_illness  ...  ethnicity  sex             needs  age_1  \
# 0                    n  ...        NaN  NaN    noneOfTheAbove    <26
# 1                    n  ...  caucasian    f              food    <26
# 2                    n  ...        NaN  NaN    noneOfTheAbove  45-64
# 3                    n  ...        NaN  NaN    noneOfTheAbove  45-64
# 4                    n  ...        NaN  NaN  financialSupport    <26
#
#   mental_health_impact travel_work_school self_isolating     media_channels  \
# 0                  NaN                NaN            NaN                NaN
# 1             noImpact  stoppedTravelling              y  twitter;tv;reddit
# 2                  NaN                NaN            NaN                NaN
# 3                  NaN                NaN            NaN                NaN
# 4                  NaN                NaN            NaN                NaN
#
#   financial_obligations_impact tobacco_usage
# 0                          NaN           NaN
# 1                          NaN             n
# 2                          NaN           NaN
# 3                          NaN           NaN
# 4                          NaN           NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# Quick sanity checks

# %%
df3.shape
df3.columns
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15534 entries, 0 to 15533
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   month                         15534 non-null  object
#  1   fsa                           15534 non-null  object
#  2   probable                      15534 non-null  object
#  3   vulnerable                    15534 non-null  object
#  4   fever_chills_shakes           15534 non-null  object
#  5   cough                         15534 non-null  object
#  6   shortness_of_breath           15534 non-null  object
#  7   any_medical_conditions        15534 non-null  object
#  8   travel_outside_canada         15534 non-null  object
#  9   contact_with_illness          15534 non-null  object
#  10  contact_in_household          159 non-null    object
#  11  tested                        15534 non-null  object
#  12  covid_results_date            421 non-null    object
#  13  covid_positive                490 non-null    object
#  14  symptoms                      793 non-null    object
#  15  conditions                    1429 non-null   object
#  16  ethnicity                     298 non-null    object
#  17  sex                           8682 non-null   object
#  18  needs                         15534 non-null  object
#  19  age_1                         15534 non-null  object
#  20  mental_health_impact          8687 non-null   object
#  21  travel_work_school            8680 non-null   object
#  22  self_isolating                8679 non-null   object
#  23  media_channels                5702 non-null   object
#  24  financial_obligations_impact  916 non-null    object
#  25  tobacco_usage                 8678 non-null   object
# dtypes: object(26)
# memory usage: 3.1+ MB

# %% [markdown]
# Reasoning
#
# info() → missing values & data types
#
# describe(include="all") → category frequency

# %% [markdown]
# Remove duplicates

# %%
initial_rows = len(df3)

df3 = df3.drop_duplicates()

print(f"Removed {initial_rows - len(df3)} duplicate rows")

# %% [markdown]
# Standardize column names
#
# Cleaner names = easier modeling later.

# %%
df3.columns = (
    df3.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

# %% [markdown]
# Identify missing values properly

# %%
missing_summary = df3.isna().mean().sort_values(ascending=False)
missing_summary
# Out:
# contact_in_household            0.987654
# ethnicity                       0.976803
# covid_results_date              0.967288
# covid_positive                  0.961862
# symptoms                        0.937643
# financial_obligations_impact    0.928285
# conditions                      0.891641
# media_channels                  0.558937
# tobacco_usage                   0.334985
# self_isolating                  0.334906
# travel_work_school              0.334827
# sex                             0.334670
# mental_health_impact            0.334277
# travel_outside_canada           0.000000
# contact_with_illness            0.000000
# fever_chills_shakes             0.000000
# vulnerable                      0.000000
# probable                        0.000000
# fsa                             0.000000
# month                           0.000000
# any_medical_conditions          0.000000
# shortness_of_breath             0.000000
# cough                           0.000000
# tested                          0.000000
# needs                           0.000000
# age_1                           0.000000
# dtype: float64

# %% [markdown]
# Reasoning:
#
# Columns with >40–50% missing often:
#
# Were optional survey questions
#
# Should be treated as "unknown" not dropped

# %% [markdown]
# Normalize binary yes/no columns
#
# First identify them:

# %%
binary_cols = [
    col for col in df3.columns
    if set(df3[col].dropna().unique()).issubset({"y", "n"})
]
binary_cols
# Out:
# ['probable',
#  'vulnerable',
#  'fever_chills_shakes',
#  'cough',
#  'shortness_of_breath',
#  'any_medical_conditions',
#  'travel_outside_canada',
#  'contact_with_illness',
#  'contact_in_household',
#  'tested',
#  'self_isolating']

# %% [markdown]
# Convert:

# %%
df3[binary_cols] = df3[binary_cols].replace({"y": 1, "n": 0})
# Out:
# C:\Users\varle\AppData\Local\Temp\ipykernel_55196\2414133756.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df3[binary_cols] = df3[binary_cols].replace({"y": 1, "n": 0})

# %% [markdown]
# Handle missing values
# Rule of thumb for survey data:
#
# Binary columns → missing = 0 (not reported)
#
# Categorical columns → "unknown"

# %%
# Binary columns
df3[binary_cols] = df3[binary_cols].fillna(0)

# Remaining categorical columns
categorical_cols = df3.select_dtypes(include="object").columns

df3[categorical_cols] = df3[categorical_cols].fillna("unknown")

# %% [markdown]
# : Clean age column (age_1)
#
# Typical problem: bucket strings like <26, 26-40, >60

# %%
df3["age_1"].value_counts()
# Out:
# age_1
# 45-64    5054
# 26-44    4300
# >65      1795
# <26      1568
# Name: count, dtype: int64

# %% [markdown]
# Optional: map to ordinal values (if needed)

# %%
age_map = {
    "<26": 1,
    "26-40": 2,
    "41-60": 3,
    ">60": 4,
    "unknown": np.nan
}

df3["age_group"] = df3["age_1"].map(age_map)

# %% [markdown]
# Normalize sex & ethnicity

# %%
df3["sex"] = (
    df3["sex"]
    .str.lower()
    .replace({
        "male": "male",
        "female": "female",
        "other": "other",
        "unknown": "unknown"
    })
)

# %% [markdown]
# cleaning ethnicity
# Inspect raw values

# %%
df3["ethnicity"].value_counts(dropna=False)
# Out:
# ethnicity
# unknown                                                 12422
# caucasian;hispanic/latino                                  21
# east asian;caucasian                                       21
# caucasian;firstNations                                     19
# caucasian;other                                            18
#                                                         ...
# firstNations;inuit;black/african;caucasian                  1
# caucasian;east asian;other                                  1
# black/african;south asian;east asian;caucasian              1
# caucasian;premieres nations                                 1
# black/african;south asian;east asian;hispanic/latino        1
# Name: count, Length: 63, dtype: int64

# %%
Normalize ethnicity values

# %%
download clean file

# %%
output_path = r"C:\Users\varle\Downloads\cleaned_schema_3_ontario.csv"

df3.to_csv(output_path, index=False)

print("Cleaned file saved successfully to Downloads folder")
# Out:
# Cleaned file saved successfully to Downloads folder
