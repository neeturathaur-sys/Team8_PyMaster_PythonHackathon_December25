# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import numpy as np

# %%
import pandas as pd

df2 = pd.read_csv(
    r"C:\Users\varle\OneDrive\Documents\GitHub\Team8_PyMaster_PythonHackathon_December25\schema_2_ontario_final.csv"
)

df2.head()
# Out:
#    week  fsa probable vulnerable is_most_recent fever_chills_shakes cough  \
# 0    15  M1P        n          n              y                   n     n
# 1    16  N2P        n          y              y                   n     n
# 2    16  N2P        n          y              n                   n     n
# 3    16  M4P        n          n              y                   n     n
# 4    16  L4N        n          n              y                   n     n
#
#   shortness_of_breath any_medical_conditions travel_outside_canada  \
# 0                   n                      y                     n
# 1                   n                      y                     n
# 2                   n                      y                     n
# 3                   n                      y                     n
# 4                   n                      y                     n
#
#   contact_with_illness   symptoms         conditions  ethnicity sex  \
# ...

# %%
df2.head()
df2.tail()
df2.shape
df2.columns
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14932 entries, 0 to 14931
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   week                    14932 non-null  int64
#  1   fsa                     14932 non-null  object
#  2   probable                14932 non-null  object
#  3   vulnerable              14932 non-null  object
#  4   is_most_recent          14932 non-null  object
#  5   fever_chills_shakes     14932 non-null  object
#  6   cough                   14932 non-null  object
#  7   shortness_of_breath     14932 non-null  object
#  8   any_medical_conditions  14932 non-null  object
#  9   travel_outside_canada   14932 non-null  object
#  10  contact_with_illness    14932 non-null  object
#  11  symptoms                1796 non-null   object
#  12  conditions              4728 non-null   object
#  13  ethnicity               7101 non-null   object
# ...

# %% [markdown]
# Missing Value analysis

# %%
df2.isna().sum().sort_values(ascending=False)
# Out:
# symptoms                  13136
# conditions                10204
# ethnicity                  7831
# needs                      7831
# week                          0
# fsa                           0
# probable                      0
# vulnerable                    0
# is_most_recent                0
# any_medical_conditions        0
# shortness_of_breath           0
# cough                         0
# fever_chills_shakes           0
# travel_outside_canada         0
# contact_with_illness          0
# sex                           0
# age_1                         0
# dtype: int64

# %% [markdown]
# Duplicate records

# %%
df1.duplicated().sum()
# Out:
# np.int64(3902)

# %% [markdown]
# 3902 Duplicate rows are  duplicate in Data set

# %% [markdown]
# check Total rows

# %%
df1.shape
# Out:
# (14932, 17)

# %% [markdown]
# 14932 -3902 =11030

# %% [markdown]
# 2.Inspect duplicate rows

# %%
df2[df2.duplicated()].head()
# Out:
#      week  fsa probable vulnerable is_most_recent fever_chills_shakes cough  \
# 45     15  K0H        n          y              n                   n     n
# 71     15  M6G        n          n              n                   n     n
# 101    15  M6S        n          n              y                   n     n
# 128    15  K1R        n          n              n                   n     n
# 129    15  K1R        n          n              n                   n     n
#
#     shortness_of_breath any_medical_conditions travel_outside_canada  \
# 45                    n                      y                     n
# 71                    n                      y                     n
# 101                   n                      y                     n
# 128                   n                      y                     n
# 129                   n                      y                     n
#
#     contact_with_illness symptoms conditions ethnicity sex needs  age_1
# ...

# %% [markdown]
# drop Duplicate rows

# %%
df2_clean = df2.drop_duplicates()

# %% [markdown]
#  Verify duplicates are removed

# %%
df2_clean.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Data Cleaning Order
# Reset index

# %%
df2_clean.reset_index(drop=True, inplace=True)

# %%
df2_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11030 entries, 0 to 11029
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   week                    11030 non-null  int64
#  1   fsa                     11030 non-null  object
#  2   probable                11030 non-null  object
#  3   vulnerable              11030 non-null  object
#  4   is_most_recent          11030 non-null  object
#  5   fever_chills_shakes     11030 non-null  object
#  6   cough                   11030 non-null  object
#  7   shortness_of_breath     11030 non-null  object
#  8   any_medical_conditions  11030 non-null  object
#  9   travel_outside_canada   11030 non-null  object
#  10  contact_with_illness    11030 non-null  object
#  11  symptoms                1633 non-null   object
#  12  conditions              4216 non-null   object
#  13  ethnicity               5980 non-null   object
# ...

# %%
print(df2_clean.columns.tolist())
# Out:
# ['week', 'fsa', 'probable', 'vulnerable', 'is_most_recent', 'fever_chills_shakes', 'cough', 'shortness_of_breath', 'any_medical_conditions', 'travel_outside_canada', 'contact_with_illness', 'symptoms', 'conditions', 'ethnicity', 'sex', 'needs', 'age_1']

# %%
binary_cols = [
    'probable',
    'vulnerable',
    'is_most_recent',
    'fever_chills_shakes',
    'cough',
    'shortness_of_breath',
    'any_medical_conditions',
    'travel_outside_canada',
    'contact_with_illness'
]

# %%
binary_cols = [
    'probable',
    'vulnerable',
    'is_most_recent',
    'fever_chills_shakes',
    'cough',
    'shortness_of_breath',
    'any_medical_conditions',
    'travel_outside_canada',
    'contact_with_illness'
]

# Standardize yes/no values → 0/1
df2_clean[binary_cols] = (
    df2_clean[binary_cols]
    .apply(lambda col: col.astype(str).str.strip().str.lower())
    .replace({
        'y': 1, 'yes': 1, 'true': 1,
        'n': 0, 'no': 0, 'false': 0
    })
)
# Out:
# C:\Users\varle\AppData\Local\Temp\ipykernel_19664\3778471517.py:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .replace({
# C:\Users\varle\AppData\Local\Temp\ipykernel_19664\3778471517.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_clean[binary_cols] = (

# %% [markdown]
# Check missing values

# %%
df2_clean.isna().sum().sort_values(ascending=False)
# Out:
# symptoms                  9397
# conditions                6814
# ethnicity                 5050
# needs                     5050
# week                         0
# fsa                          0
# probable                     0
# vulnerable                   0
# is_most_recent               0
# any_medical_conditions       0
# shortness_of_breath          0
# cough                        0
# fever_chills_shakes          0
# travel_outside_canada        0
# contact_with_illness         0
# sex                          0
# age_1                        0
# dtype: int64

# %%
df2_clean['week'] = pd.to_numeric(df2_clean['week'], errors='coerce')
# Out:
# C:\Users\varle\AppData\Local\Temp\ipykernel_19664\1365960622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_clean['week'] = pd.to_numeric(df2_clean['week'], errors='coerce')

# %% [markdown]
# convert week in to  mont

# %%
df2['month'] = df2['date'].dt.to_period('M').astype(str)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ...

# %% [markdown]
# Then convert week to numeric or datetime, not date.
